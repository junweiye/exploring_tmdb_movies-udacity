# %% [markdown]
# # 项目：调查数据集（IMDB数据集探索）
#
# ## 目录
# <ul>
# <li><a href="#intro">简介</a></li>
# <li><a href="#wrangling">数据整理</a></li>
# <li><a href="#eda">探索性数据分析</a></li>
# <li><a href="#conclusions">结论</a></li>
# </ul>
#
# <a id='intro'></a>
# ## 简介
#
# 根据对数据集的简单理解，选择了genres和release_date两个自变量统计数值进行分析，在此之前先根据这两个变量的数据特征进行数据整理。
# 问题一：不同电影风格数量的对比
# 问题二：电影上映日期的分布

# %%
#   导入语句。
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## 数据整理
#
#
# ### 常规属性

# %%
# 加载数据并打印前几行
df=pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# 查看数据的行数和列数
df.shape
# Out:
# (10866, 21)

# %%
# 查看每列数据的数据类型
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
# 检查缺失值
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# 发现需要研究的变量genres存在缺失值，数量为23个，占样本行数的0.2%，
# 进一步查看genres缺失值对应的行的信息，发现这些行其他列的数值也存在大量空缺，缺乏研究价值，所以可以去掉
df[df['genres'].isnull()]
# Out:
#            id    imdb_id  popularity  budget  revenue  \
# 424    363869  tt4835298    0.244648       0        0
# 620    361043  tt5022680    0.129696       0        0
# 997    287663        NaN    0.330431       0        0
# 1712    21634  tt1073510    0.302095       0        0
# 1897    40534  tt1229827    0.020701       0        0
# 2370   127717  tt1525359    0.081892       0        0
# 2376   315620  tt1672218    0.068411       0        0
# 2853    57892  tt0270053    0.130018       0        0
# 3279    54330  tt1720044    0.145331       0        0
# 4547   123024  tt2305700    0.520520       0        0
# 4732   139463  tt2084977    0.235911       0        0
# 4797   369145        NaN    0.167501       0        0
# 4890   126909  tt2219564    0.083202       0        0
# 5830   282848  tt2986512    0.248944       0        0
# 5934   200204  tt2808968    0.067433       0        0
# 6043   190940  tt2797242    0.039080       0        0
# ...

# %%
# 检查是否有重复数值并查看这些重复值的分布
df[df.duplicated(keep=False)]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2089  42194  tt0411951     0.59643  30000000   967000         TEKKEN
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline     ...       \
# 2089  Dwight H. Little  Survival is no game     ...
# 2090  Dwight H. Little  Survival is no game     ...
#
#                                                overview runtime  \
# 2089  In the year of 2039, after World Wars destroy ...      92
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2089  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
# ...

# %%
# 去重并再次检查重复数值
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 去除缺失值及切割genres

# %%
# 去掉‘genres'列的缺失值
df.dropna(subset = ['genres'],inplace=True)

# %%
#切割genres列的数据
df_genres = df.drop('genres', axis=1).join(df['genres'].str.split('|', expand=True)\
                                           .stack().reset_index(level=1, drop=True).rename('genres'))

# %%
df_genres.shape
# Out:
# (26955, 21)

# %% [markdown]
# <a id='eda'></a>
# ## 探索性数据分析
#
#
# ### 研究问题 1（电影行业利润的年代变化）

# %%
# 通过已知的预算和收入数据计算利润，并通过groupby汇总
df['profit']=df['revenue_adj']-df['budget_adj']
df_profit=df.groupby(df['release_year'])['profit'].sum()


df_profit.plot(kind='line',figsize=(10,10));
plt.title('movies_total_profits_by_year ');
plt.xlabel('release_year');
plt.ylabel('profits');

# %% [markdown]
# ### 电影票房利润整体呈逐年上升的趋势，21世纪以后涨幅的更高。

# %% [markdown]
# ### 研究问题 2（不同年代最卖座的电影类型）

# %%
# 通过groupby呈现release_year,genres的revenue求和数据，再通过unstack与max、idmax函数求出最卖座电影的revenue及对应的电影类型
figure, ax1 = plt.subplots()

target = df_genres.groupby(['release_year', 'genres'])['revenue_adj'].sum().unstack(level=0)
target.max().plot(kind='bar', figsize=(18, 5), color='purple', grid=True, axes=ax1)

ax2 = ax1.twiny()
ax2.set_xticklabels(target.idxmax(), rotation=90)
ax2.set_xticks(ax1.get_xticks()+0.5)
ax2.tick_params(pad=15)

ax1.set_ylabel('sum of revenue')
ax2.set_xlabel('genres')
plt.show()

# %%
# 统计历年最卖座的电影类型汇总
target.idxmax().value_counts().plot(kind='bar');

# %% [markdown]
# ### 从上述图表可以看出，最卖座电影类型的收入趋势整体是上升的。这其中Drama成为最卖座的电影类型的次数最多。

# %% [markdown]
# <a id='conclusions'></a>
# ## 结论
# 结论一：根据样本数据集的数据，可以看出电影票房利润整体为上升的趋势，21世纪以后涨幅的更高。因为并不确定该样本数据集占据所有电影数据的比例，所以无法完全推断整个电影工业的趋势。
#
# 结论二：根据样本数据集的数据，最卖座电影类型的收入趋势整体是上升的。这其中Drama成为最卖座的电影类型的次数最多，但是因为数据集中的每部电影所对应的电影类型可能不止一个，电影收入被重复统计，所以结果并不准确。如果能将每部电影对应一个最主要的电影类型，则样本数据集的结果准确度会高一些。

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 255
